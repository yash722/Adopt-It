# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np
import time
import urllib.request

opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36')]
urllib.request.install_opener(opener)

# %%
# Run once (Already Ran)!
options = webdriver.ChromeOptions()
options.add_argument('--headless')
browser = webdriver.Chrome(options=options)
browser.get("https://www.mspca.org/adoption-search/?type=dog")
time.sleep(2)
dogs = browser.find_elements(By.CLASS_NAME, 'petCard')
data = {
    "Name" : [],
    "Breed":[],
    "Location": [],
    "Gender" : [],
    "Age":[],
    "Weight":[],
    "Image": [],
    "Description":[]
}
dogs = [i for i in dogs if i.text != ""]
l = ["Location", "Gender", "Age", "Weight"]
for dog in dogs:
    dog_link = dog.get_attribute("href")
    print(dog_link)
    time.sleep(5)
    br_dog = webdriver.Chrome(options=options)
    br_dog.get(dog_link)
    dog_image = br_dog.find_element(By.ID, "extraimage0")
    dog_image = dog_image.get_attribute("src")
    data["Image"].append(dog_image)
    dog_name = br_dog.find_element(By.TAG_NAME, "h1").text
    data["Name"].append(dog_name)
    dog_breed = br_dog.find_element(By.XPATH, '/html/body/div[6]/div[1]/div[1]/div[2]/h2').text
    data["Breed"].append(dog_breed)
    print(dog_image, dog_name, dog_breed)
    dog_info = br_dog.find_elements(By.CLASS_NAME, "petStatContent")
    dog_info = [i for i in dog_info if i.text != ""]
    for i in range(len(dog_info)):
        dog_data = dog_info[i].find_element(By.TAG_NAME, "span").text
        data[l[i]].append(dog_data)
        print(dog_data)
    dog_bio = br_dog.find_element(By.CLASS_NAME, "petBio")
    dog_desc = dog_bio.find_elements(By.TAG_NAME, "p")
    total_description = ""
    for desc in dog_desc:
        total_description += " " + desc.text
    data["Description"].append(total_description)
    br_dog.close()


browser.close()
# Out:
# https://www.mspca.org/pets/a422418/
# https://www.mspca.org/wp-content/uploads/2023/06/Wendy.jpg?1700198752 Wendy Great Dane / Pit Bull Terrier
# Nevins Farm
# Female
# 5 Years
# 88.18
# https://www.mspca.org/pets/a431301/
# https://www.mspca.org/wp-content/uploads/2023/09/Rilee1-1-1024x1024.jpg?1700198760 Rilee Pit Bull Terrier
# Nevins Farm
# Female
# 7 Years
# 68.12
# https://www.mspca.org/pets/a427555/
# https://www.mspca.org/wp-content/uploads/2023/09/4-3.jpeg?1700198771 Georgie Labrador Retriever Mix
# Cape Cod
# Male
# 8 Years
# 69.45
# https://www.mspca.org/pets/a423978/
# https://www.mspca.org/wp-content/uploads/2023/09/Screenshot_20231108_105420_Outlook-810x1024.jpg?1700198781 Skylar Pit Bull Terrier
# Nevins Farm
# Female
# 1 Years
# 18.74
# https://www.mspca.org/pets/a431294/
# https://www.mspca.org/wp-content/uploads/2023/09/IMG_20231108_104136.jpg?1700198791 Ace Pit Bull Terrier
# Nevins Farm
# Male
# 1 Years
# 59.52
# https://www.mspca.org/pets/a433927/
# ...

# %%
print(data)
# Out:
# {'Name': ['Wendy', 'Rilee', 'Georgie', 'Skylar', 'Ace', 'Joule', 'Nala', 'Daisy', 'Tammy', 'Rose', 'Kappa', 'Dewey', 'Daryl', 'Bozo', 'Roxy', 'Kodiak', 'Beverly', 'Onyx', 'Blue', 'Maxy', 'Al', 'Nelly', 'Charlie', 'Dahlia', 'Luna', 'Ben', 'Reba', 'Ellie', 'Patsy', 'Doug', 'Chester', 'Sneakers', 'Sierra', 'Sox', 'Jamie', 'Vegas', 'Hanna', 'Snowky', 'Waylon', 'Willie', 'Churro', 'Jacie', 'Farrah', 'Dolly', 'Mason', 'Joseph', 'Nutmeg', 'Ezra', 'Aragorn', 'Cody', 'Colors', 'Baxley', 'Ginny', 'Jasper', 'Bonnye'], 'Breed': ['Great Dane / Pit Bull Terrier', 'Pit Bull Terrier', 'Labrador Retriever Mix', 'Pit Bull Terrier', 'Pit Bull Terrier', 'Boxer / Pit Bull Terrier', 'German Shepherd Dog Mix', 'Beagle / Catahoula Leopard Hound', 'American Pit Bull Terrier Mix', 'Labrador Retriever Mix', 'Pit Bull Terrier Mix', 'Pit Bull Terrier', 'Labrador Retriever Mix', 'Pit Bull Terrier Mix', 'Pit Bull Terrier', 'Siberian Husky Mix', 'Labrador Retriever Mix', 'Labrador Retriever Mix', 'Siberian Husky', 
# ...

# %%
df_dogs = pd.DataFrame(data)

# %%
df_dogs
# Out:
#         Name                             Breed     Location  Gender  \
# 0      Wendy     Great Dane / Pit Bull Terrier  Nevins Farm  Female
# 1      Rilee                  Pit Bull Terrier  Nevins Farm  Female
# 2    Georgie            Labrador Retriever Mix     Cape Cod    Male
# 3     Skylar                  Pit Bull Terrier  Nevins Farm  Female
# 4        Ace                  Pit Bull Terrier  Nevins Farm    Male
# 5      Joule          Boxer / Pit Bull Terrier  Nevins Farm  Female
# 6       Nala           German Shepherd Dog Mix       Boston  Female
# 7      Daisy  Beagle / Catahoula Leopard Hound  Nevins Farm  Female
# 8      Tammy     American Pit Bull Terrier Mix        Salem  Female
# 9       Rose            Labrador Retriever Mix        Salem  Female
# 10     Kappa              Pit Bull Terrier Mix       Boston  Female
# 11     Dewey                  Pit Bull Terrier       Boston    Male
# 12     Daryl            Labrador Retriever Mix  Nevins Farm    Male
# ...

# %%
# Already Saved!
df_dogs.to_csv("Dogs_From_MSPCA.csv", index=False)

# %%
df_dogs = pd.read_csv("Dogs_From_MSPCA.csv")

# %%
dog_image_urls = df_dogs["Image"].values
dog_names = df_dogs["Name"].values
for i in range(dog_image_urls.shape[0]):
    urllib.request.urlretrieve(dog_image_urls[i], f"Dog_Images/{dog_names[i]}_{i}.jpg")

# %%
dog_image_urls.shape
# Out:
# (55,)
